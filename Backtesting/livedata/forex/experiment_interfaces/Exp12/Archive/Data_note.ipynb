# %%
import docs
# Out:
# MetaTrader5 package author:  MetaQuotes Ltd.
# MetaTrader5 package version:  5.0.36
# Start Measurement
# Means: {'EURUSD': [1.1887716448412697, 0.001934757095242919, 0.0014980142863479015, 0.9822420634920634]}
# Time: 1.4832454999999989

# %%
import pandas as pd
rates_frame = pd.DataFrame(docs.rates)
rates_frame['time']=pd.to_datetime(rates_frame['time'], unit='s')
rates_frame[['time', 'close']]
# Out:
#                      time    close
# 0     2017-12-19 18:00:00  1.18065
# 1     2017-12-19 18:01:00  1.18066
# 2     2017-12-19 18:02:00  1.18086
# 3     2017-12-19 18:03:00  1.18091
# 4     2017-12-19 18:04:00  1.18079
# ...                   ...      ...
# 10075 2017-12-29 23:55:00  1.20012
# 10076 2017-12-29 23:56:00  1.19995
# 10077 2017-12-29 23:57:00  1.20040
# 10078 2017-12-29 23:58:00  1.20042
# 10079 2017-12-29 23:59:00  1.20025
#
# [10080 rows x 2 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

a4_dims = (11.7, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
sns.lineplot(data = rates_frame[['time','close']], x='time', y='close', ax=ax)
plt.plot([rates_frame['time'][0], rates_frame['time'].iloc[-1]],[docs.means_data['EURUSD'][0], docs.means_data['EURUSD'][0]] , linewidth=2)
